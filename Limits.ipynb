# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **$ \lim\limits_{x \to \infty} \frac{1}{x} = 0$**

# %%
x = np.linspace(1, 100, 1000)
y = 1 / x

# %%
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.plot(x, y);

# %%
x = 1e100
1/x
# Out:
# 1e-100

# %%
# limitations in floating point accuracy due to hardware (number of bits in floating point representation)
x = 1e500
1/x
# Out:
# 0.0

# %% [markdown]
# $ \lim\limits_{x \to \pi / 2} \tan(x) = DNE$

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 100000)
y = np.tan(x)

# %%
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.plot(x, y);

# %%
x = np.pi / 2 - 1e-10
np.tan(x)
# Out:
# np.float64(9999993049.367125)

# %%
x = np.pi / 2 + 1e-10
np.tan(x)
# Out:
# np.float64(-10000005295.83309)

# %% [markdown]
# $ \lim\limits_{x \to \infty} \frac{\ln x}{x} = 0$

# %%
x = 1e100
np.log(x) / x
# Out:
# np.float64(2.302585092994046e-98)

# %% [markdown]
# $ \lim\limits_{x \to \infty} \left( 1 + \frac{1}{x} \right)^x = e$

# %%
np.e
# Out:
# 2.718281828459045

# %%
x = 1e2
(1 + 1/x)**x
# Out:
# 2.7048138294215285

# %%
x = 1e3
(1 + 1/x)**x
# Out:
# 2.7169239322355936

# %%
x = 1e4
(1 + 1/x)**x
# Out:
# 2.7181459268249255

# %%
x = 1e5
(1 + 1/x)**x
# Out:
# 2.7182682371922975

# %%
x = 1e10
(1 + 1/x)**x
# Out:
# 2.7182820532347876

# %%
x = 1e20 # oops! precision problems
# Here due to precision problem 1 + 1/x got approximated to 1. Then 1 was raised to large power giving 1.
(1 + 1/x)**x
# Out:
# 1.0

# %% [markdown]
# **$ \lim\limits_{x \to \infty} \frac{\sin(x)}{x} = 0$**

# %%
x = 1e100
np.sin(x) / x
# Out:
# np.float64(-3.806377310050287e-101)

# %% [markdown]
# **$ \lim\limits_{x \to 0} \frac{\sin(x)}{x} = 1$**

# %%
x = 1e-10
np.sin(x) / x
# Out:
# np.float64(1.0)

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=u00sXRNZFNmp4Ka08-CGPw&n=Limits)
